# %% [markdown]
# # List Comprehension (리스트 내포)
#
# 이 노트북은 **list comprehension**을 이해하기 위한
# 👉 설명 + 실습 예제 **30개**로 구성되어 있습니다.
#
# ---
#
# ## 기본 문법
#
# ```python
# [표현식 for 변수 in 반복가능한것]
# [표현식 for 변수 in 반복가능한것 if 조건]
# [참일때값 if 조건 else 거짓일때값 for 변수 in 반복가능한것]
# ```
#
# - 짧고 가독성 좋은 반복 처리
# - 기존 for문을 한 줄로 표현

# %% [markdown]
# ## 1. 기본 형태

# %%
a = [i for i in range(10)]
a

# %%
b = [i*i for i in range(1, 11)]
b

# %%
c = [i for i in range(1, 21) if i % 2 == 0]
c

# %% [markdown]
# ## 2. 조건 포함

# %%
odd = [i for i in range(1, 21) if i % 2 == 1]
odd

# %%
m7 = [i for i in range(1, 101) if i % 7 == 0]
m7

# %%
pos = [x for x in [-3, -1, 0, 2, 5] if x > 0]
pos

# %% [markdown]
# ## 3. if-else 포함 (삼항 연산)

# %%
labels = ['짝수' if i % 2 == 0 else '홀수' for i in range(1, 11)]
labels

# %%
scores = [95, 60, 72, 40]
result = ['합격' if s >= 70 else '불합격' for s in scores]
result

# %% [markdown]
# ## 4. 문자열 처리

# %%
word = 'beautiful'
vowels = [c for c in word if c in 'aeiou']
vowels

# %%
names = ['han', 'kim', 'lee']
upper = [n.upper() for n in names]
upper

# %%
text = 'AbCdE'
toggle = [c.lower() if c.isupper() else c.upper() for c in text]
''.join(toggle)

# %% [markdown]
# ## 5. 리스트 가공

# %%
nums = [1, -2, 3, -4]
abs_vals = [abs(x) for x in nums]
abs_vals

# %%
clean = [x.strip() for x in [' a ', ' ', 'b'] if x.strip()]
clean

# %%
lengths = [len(w) for w in ['빵', '저온숙성', '생지']]
lengths

# %% [markdown]
# ## 6. 중첩 list comprehension

# %%
pairs = [(x, y) for x in range(3) for y in range(3)]
pairs

# %%
matrix = [[1,2],[3,4],[5,6]]
flat = [n for row in matrix for n in row]
flat

# %%
gugu = [a*b for a in range(2, 10) for b in range(1, 10)]
gugu[:10]

# %% [markdown]
# ## 7. enumerate 활용

# %%
items = ['A','B','C']
indexed = [(i, v) for i, v in enumerate(items)]
indexed

# %%
even_index = [v for i, v in enumerate(items) if i % 2 == 0]
even_index

# %% [markdown]
# ## 8. 딕셔너리와 함께 사용

# %%
pay = {'사원':230, '대리':280, '과장':350}
values = [v for v in pay.values()]
values

# %%
keys = [k for k in pay.keys()]
keys

# %%
kv = [f'{k}:{v}' for k, v in pay.items()]
kv

# %% [markdown]
# ## 9. 실전 응용

# %%
data = [1,1,2,2,3,1]
unique = [x for i, x in enumerate(data) if x not in data[:i]]
unique

# %%
products = ['크루아상','식빵','단팥빵','소금빵']
bread = [p for p in products if '빵' in p]
bread

# %%
squares = [i for i in range(1, 51) if int(i**0.5)**2 == i]
squares

# %% [markdown]
# ## 10. 요약 체크

# %% [markdown]
# - list comprehension은 **반복 + 조건 + 가공**을 한 줄로 처리
# - 복잡해지면 일반 for문이 더 좋을 수도 있음
# - **가독성 우선**으로 사용
